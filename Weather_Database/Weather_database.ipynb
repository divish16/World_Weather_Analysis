# %%
# import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import matplotlib.pyplot as plt
# import requests
import requests

# %%
# create a list of 2000 random lats and longs
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# create a list for lats and longs
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []
# identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 744

# %%
# import dependencies 
from config import weather_api_key

# %%
# performing api call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | susangerd
# Processing Record 2 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | antalya
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | nabire
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | shar
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | karratha
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | havre-saint-pierre
# Processing Record 17 of Set 1 | makung
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | inhambane
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | kimparana
# Processing Record 23 of Set 1 | pamplona
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | surok
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | airai
# Processing Record 29 of Set 1 | mahibadhoo
# Processing Record 30 of Set 1 | purranque
# Processing Record 31 of Set 1 | kamenka
# Processing Record 32 of Set 1 | pacific grove
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | nyurba
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | saldanha
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | yomitan
# City not found. Skipping...
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | mapiri
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | asau
# Processing Record 1 of Set 2 | portland
# Processing Record 2 of Set 2 | acarau
# Processing Record 3 of Set 2 | la ronge
# Processing Record 4 of Set 2 | dunedin
# Processing Record 5 of Set 2 | yinchuan
# Processing Record 6 of Set 2 | angoram
# Processing Record 7 of Set 2 | yar-sale
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | ulaangom
# Processing Record 10 of Set 2 | bilibino
# Processing Record 11 of Set 2 | kununurra
# Processing Record 12 of Set 2 | chara
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | pisco
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | parana
# Processing Record 21 of Set 2 | brae
# Processing Record 22 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | inta
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | abha
# Processing Record 27 of Set 2 | cherskiy
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | bentiu
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 2 | itupiranga
# Processing Record 33 of Set 2 | kirkland lake
# Processing Record 34 of Set 2 | balkanabat
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | loa janan
# Processing Record 38 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 2 | simbahan
# Processing Record 40 of Set 2 | maniitsoq
# Processing Record 41 of Set 2 | baykit
# Processing Record 42 of Set 2 | haines junction
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | qaqortoq
# Processing Record 45 of Set 2 | poum
# Processing Record 46 of Set 2 | pathein
# Processing Record 47 of Set 2 | kenai
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | ishurdi
# Processing Record 1 of Set 3 | mbanza-ngungu
# Processing Record 2 of Set 3 | busselton
# Processing Record 3 of Set 3 | dagana
# Processing Record 4 of Set 3 | santa cruz
# Processing Record 5 of Set 3 | luderitz
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | turukhansk
# Processing Record 9 of Set 3 | grande prairie
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | lae
# Processing Record 15 of Set 3 | kruisfontein
# Processing Record 16 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 17 of Set 3 | aksarka
# Processing Record 18 of Set 3 | dalby
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | albany
# Processing Record 21 of Set 3 | sinjai
# Processing Record 22 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | mackay
# Processing Record 24 of Set 3 | danilovka
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | arman
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | sakakah
# Processing Record 29 of Set 3 | valleyview
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | lieksa
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | smidovich
# Processing Record 34 of Set 3 | dakar
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | pitimbu
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | indapur
# Processing Record 40 of Set 3 | sitka
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | taltal
# Processing Record 43 of Set 3 | quelimane
# Processing Record 44 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 3 | beringovskiy
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 3 | sola
# Processing Record 50 of Set 3 | macau
# Processing Record 1 of Set 4 | tarnow
# Processing Record 2 of Set 4 | iquitos
# Processing Record 3 of Set 4 | padang
# Processing Record 4 of Set 4 | kudahuvadhoo
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | talakan
# Processing Record 8 of Set 4 | olinda
# Processing Record 9 of Set 4 | sistranda
# Processing Record 10 of Set 4 | shingu
# Processing Record 11 of Set 4 | kavieng
# Processing Record 12 of Set 4 | oktyabrskiy
# Processing Record 13 of Set 4 | vardo
# Processing Record 14 of Set 4 | moron
# Processing Record 15 of Set 4 | kargalinskaya
# Processing Record 16 of Set 4 | blythe
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | east london
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | red bluff
# Processing Record 21 of Set 4 | coihaique
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | acandi
# Processing Record 28 of Set 4 | vodstroy
# Processing Record 29 of Set 4 | luanda
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | san cristobal
# Processing Record 32 of Set 4 | kirkcudbright
# Processing Record 33 of Set 4 | yeppoon
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | sept-iles
# Processing Record 37 of Set 4 | prince rupert
# Processing Record 38 of Set 4 | kamaishi
# Processing Record 39 of Set 4 | camopi
# Processing Record 40 of Set 4 | abeche
# Processing Record 41 of Set 4 | iralaya
# Processing Record 42 of Set 4 | phuket
# Processing Record 43 of Set 4 | mayor pablo lagerenza
# Processing Record 44 of Set 4 | awjilah
# Processing Record 45 of Set 4 | porto velho
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | nesna
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | komsomolskiy
# Processing Record 1 of Set 5 | moundou
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | hailar
# Processing Record 5 of Set 5 | shahrud
# Processing Record 6 of Set 5 | plettenberg bay
# Processing Record 7 of Set 5 | heishan
# Processing Record 8 of Set 5 | ithaca
# Processing Record 9 of Set 5 | dodoma
# Processing Record 10 of Set 5 | maniwaki
# Processing Record 11 of Set 5 | etchoropo
# Processing Record 12 of Set 5 | necochea
# Processing Record 13 of Set 5 | meadow lake
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | guymon
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 5 | culaman
# Processing Record 20 of Set 5 | porbandar
# Processing Record 21 of Set 5 | lagos
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | ahipara
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | norton shores
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | ilulissat
# Processing Record 28 of Set 5 | serenje
# Processing Record 29 of Set 5 | wangqing
# Processing Record 30 of Set 5 | aljezur
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | henties bay
# Processing Record 33 of Set 5 | lebu
# Processing Record 34 of Set 5 | fuxin
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | alofi
# Processing Record 37 of Set 5 | fare
# Processing Record 38 of Set 5 | khotiv
# Processing Record 39 of Set 5 | letterkenny
# Processing Record 40 of Set 5 | soller
# Processing Record 41 of Set 5 | roald
# Processing Record 42 of Set 5 | ponta delgada
# Processing Record 43 of Set 5 | prainha
# Processing Record 44 of Set 5 | birjand
# Processing Record 45 of Set 5 | srednekolymsk
# Processing Record 46 of Set 5 | ukiah
# Processing Record 47 of Set 5 | podgorenskiy
# Processing Record 48 of Set 5 | buchanan
# Processing Record 49 of Set 5 | kirakira
# Processing Record 50 of Set 5 | yaan
# Processing Record 1 of Set 6 | gloversville
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | douentza
# Processing Record 4 of Set 6 | kargil
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | gashua
# Processing Record 7 of Set 6 | havelock
# Processing Record 8 of Set 6 | codrington
# Processing Record 9 of Set 6 | camacha
# Processing Record 10 of Set 6 | nouadhibou
# Processing Record 11 of Set 6 | antofagasta
# Processing Record 12 of Set 6 | edendale
# Processing Record 13 of Set 6 | neryungri
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | chiplun
# Processing Record 16 of Set 6 | sinnamary
# Processing Record 17 of Set 6 | batagay
# Processing Record 18 of Set 6 | port hedland
# Processing Record 19 of Set 6 | viksoyri
# City not found. Skipping...
# Processing Record 20 of Set 6 | tongren
# Processing Record 21 of Set 6 | belyy yar
# Processing Record 22 of Set 6 | batsfjord
# Processing Record 23 of Set 6 | bolshaya glushitsa
# Processing Record 24 of Set 6 | salalah
# Processing Record 25 of Set 6 | thiruvananthapuram
# Processing Record 26 of Set 6 | altay
# Processing Record 27 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 6 | sisimiut
# Processing Record 29 of Set 6 | riacho de santana
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | srandakan
# Processing Record 32 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 33 of Set 6 | burnie
# Processing Record 34 of Set 6 | bulgan
# Processing Record 35 of Set 6 | vilyuysk
# Processing Record 36 of Set 6 | ambilobe
# Processing Record 37 of Set 6 | khlevnoye
# Processing Record 38 of Set 6 | rocha
# Processing Record 39 of Set 6 | college
# Processing Record 40 of Set 6 | isabela
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | kungurtug
# Processing Record 43 of Set 6 | jimani
# Processing Record 44 of Set 6 | ankang
# Processing Record 45 of Set 6 | jacmel
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | ilheus
# Processing Record 48 of Set 6 | deer lake
# Processing Record 49 of Set 6 | tahe
# Processing Record 50 of Set 6 | tabuk
# Processing Record 1 of Set 7 | peniche
# Processing Record 2 of Set 7 | la gaulette
# City not found. Skipping...
# Processing Record 3 of Set 7 | hofn
# Processing Record 4 of Set 7 | luau
# Processing Record 5 of Set 7 | mazamari
# Processing Record 6 of Set 7 | vila velha
# Processing Record 7 of Set 7 | tecoanapa
# Processing Record 8 of Set 7 | paramonga
# Processing Record 9 of Set 7 | sambava
# Processing Record 10 of Set 7 | myingyan
# Processing Record 11 of Set 7 | ous
# Processing Record 12 of Set 7 | ravar
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | vestmanna
# Processing Record 15 of Set 7 | macherla
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | quatre cocos
# Processing Record 18 of Set 7 | bocs
# Processing Record 19 of Set 7 | maraba
# Processing Record 20 of Set 7 | santa
# Processing Record 21 of Set 7 | bambanglipuro
# Processing Record 22 of Set 7 | witu
# Processing Record 23 of Set 7 | monterey
# Processing Record 24 of Set 7 | celestun
# Processing Record 25 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 7 | yokadouma
# Processing Record 27 of Set 7 | molina
# Processing Record 28 of Set 7 | porto novo
# Processing Record 29 of Set 7 | kachug
# Processing Record 30 of Set 7 | metro
# Processing Record 31 of Set 7 | erenhot
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | burlington
# Processing Record 34 of Set 7 | namwala
# Processing Record 35 of Set 7 | dingle
# Processing Record 36 of Set 7 | dudinka
# Processing Record 37 of Set 7 | hamilton
# Processing Record 38 of Set 7 | saiha
# Processing Record 39 of Set 7 | sikonge
# Processing Record 40 of Set 7 | shache
# Processing Record 41 of Set 7 | berlevag
# Processing Record 42 of Set 7 | sidrolandia
# Processing Record 43 of Set 7 | lorengau
# Processing Record 44 of Set 7 | kalinagar
# Processing Record 45 of Set 7 | mount isa
# Processing Record 46 of Set 7 | bilma
# Processing Record 47 of Set 7 | dno
# Processing Record 48 of Set 7 | djibo
# Processing Record 49 of Set 7 | deputatskiy
# Processing Record 50 of Set 7 | ngunguru
# Processing Record 1 of Set 8 | sur
# Processing Record 2 of Set 8 | manbij
# Processing Record 3 of Set 8 | gigmoto
# Processing Record 4 of Set 8 | kenora
# Processing Record 5 of Set 8 | moustheni
# Processing Record 6 of Set 8 | chuy
# Processing Record 7 of Set 8 | bail hongal
# Processing Record 8 of Set 8 | ilhabela
# Processing Record 9 of Set 8 | kaoma
# Processing Record 10 of Set 8 | xining
# Processing Record 11 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 8 | panaba
# Processing Record 13 of Set 8 | dajal
# Processing Record 14 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 8 | avera
# Processing Record 17 of Set 8 | ingham
# Processing Record 18 of Set 8 | ankpa
# Processing Record 19 of Set 8 | bathurst
# Processing Record 20 of Set 8 | valparaiso
# Processing Record 21 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 8 | suluq
# Processing Record 23 of Set 8 | lydenburg
# Processing Record 24 of Set 8 | adjumani
# Processing Record 25 of Set 8 | wangdiphodrang
# City not found. Skipping...
# Processing Record 26 of Set 8 | iranshahr
# Processing Record 27 of Set 8 | jumla
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | umm kaddadah
# Processing Record 30 of Set 8 | morro bay
# Processing Record 31 of Set 8 | port blair
# Processing Record 32 of Set 8 | mau
# Processing Record 33 of Set 8 | namatanai
# Processing Record 34 of Set 8 | nizhneudinsk
# Processing Record 35 of Set 8 | ostrovnoy
# Processing Record 36 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 37 of Set 8 | kongolo
# Processing Record 38 of Set 8 | tiksi
# Processing Record 39 of Set 8 | metehara
# City not found. Skipping...
# Processing Record 40 of Set 8 | udachnyy
# Processing Record 41 of Set 8 | klaksvik
# Processing Record 42 of Set 8 | calvinia
# Processing Record 43 of Set 8 | sitangkai
# Processing Record 44 of Set 8 | ust-kan
# Processing Record 45 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 46 of Set 8 | maningrida
# Processing Record 47 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 8 | kobe
# Processing Record 49 of Set 8 | aklavik
# Processing Record 50 of Set 8 | los corrales de buelna
# Processing Record 1 of Set 9 | ponta do sol
# Processing Record 2 of Set 9 | halifax
# Processing Record 3 of Set 9 | souillac
# Processing Record 4 of Set 9 | kitimat
# Processing Record 5 of Set 9 | suntar
# Processing Record 6 of Set 9 | raga
# Processing Record 7 of Set 9 | finnsnes
# Processing Record 8 of Set 9 | gat
# Processing Record 9 of Set 9 | lagoa
# Processing Record 10 of Set 9 | hirara
# Processing Record 11 of Set 9 | linguere
# Processing Record 12 of Set 9 | taldan
# Processing Record 13 of Set 9 | katangli
# Processing Record 14 of Set 9 | oxapampa
# Processing Record 15 of Set 9 | ranot
# Processing Record 16 of Set 9 | chone
# Processing Record 17 of Set 9 | isoka
# Processing Record 18 of Set 9 | lavrentiya
# Processing Record 19 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 20 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 9 | davila
# Processing Record 22 of Set 9 | whitehorse
# Processing Record 23 of Set 9 | encruzilhada do sul
# Processing Record 24 of Set 9 | north bend
# Processing Record 25 of Set 9 | mareeba
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | sobolevo
# Processing Record 28 of Set 9 | otjiwarongo
# Processing Record 29 of Set 9 | faya
# Processing Record 30 of Set 9 | bousso
# Processing Record 31 of Set 9 | malm
# Processing Record 32 of Set 9 | palora
# Processing Record 33 of Set 9 | taonan
# Processing Record 34 of Set 9 | howard springs
# Processing Record 35 of Set 9 | kontagora
# Processing Record 36 of Set 9 | torit
# Processing Record 37 of Set 9 | namibe
# Processing Record 38 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 9 | yumen
# Processing Record 40 of Set 9 | poya
# Processing Record 41 of Set 9 | gunjur
# Processing Record 42 of Set 9 | kaeo
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | maceio
# Processing Record 45 of Set 9 | mahon
# Processing Record 46 of Set 9 | basco
# Processing Record 47 of Set 9 | marrakesh
# Processing Record 48 of Set 9 | boddam
# Processing Record 49 of Set 9 | belmonte
# Processing Record 50 of Set 9 | ishigaki
# Processing Record 1 of Set 10 | turayf
# Processing Record 2 of Set 10 | anadyr
# Processing Record 3 of Set 10 | shetpe
# Processing Record 4 of Set 10 | abhar
# Processing Record 5 of Set 10 | filadelfia
# Processing Record 6 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 10 | belomorsk
# Processing Record 8 of Set 10 | kattivakkam
# Processing Record 9 of Set 10 | ampanihy
# Processing Record 10 of Set 10 | alice springs
# Processing Record 11 of Set 10 | virginia beach
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | rio gallegos
# Processing Record 15 of Set 10 | lianzhou
# Processing Record 16 of Set 10 | muswellbrook
# Processing Record 17 of Set 10 | viedma
# Processing Record 18 of Set 10 | tuatapere
# Processing Record 19 of Set 10 | ust-nera
# Processing Record 20 of Set 10 | chumikan
# Processing Record 21 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 10 | bosaso
# Processing Record 23 of Set 10 | tommot
# Processing Record 24 of Set 10 | port macquarie
# Processing Record 25 of Set 10 | flinders
# Processing Record 26 of Set 10 | ixtapa
# Processing Record 27 of Set 10 | uyuni
# Processing Record 28 of Set 10 | korla
# Processing Record 29 of Set 10 | santa cruz del sur
# Processing Record 30 of Set 10 | beian
# Processing Record 31 of Set 10 | half moon bay
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | kashiwazaki
# Processing Record 34 of Set 10 | khamamatyurt
# Processing Record 35 of Set 10 | umm lajj
# Processing Record 36 of Set 10 | warmbad
# Processing Record 37 of Set 10 | hualmay
# Processing Record 38 of Set 10 | stephenville crossing
# Processing Record 39 of Set 10 | nokaneng
# Processing Record 40 of Set 10 | gamba
# Processing Record 41 of Set 10 | digha
# Processing Record 42 of Set 10 | seabra
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | tefe
# Processing Record 45 of Set 10 | pevek
# Processing Record 46 of Set 10 | deniliquin
# Processing Record 47 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 10 | tabou
# Processing Record 49 of Set 10 | penzance
# Processing Record 50 of Set 10 | banda aceh
# Processing Record 1 of Set 11 | chipata
# Processing Record 2 of Set 11 | monrovia
# Processing Record 3 of Set 11 | saint-georges
# Processing Record 4 of Set 11 | sandakan
# Processing Record 5 of Set 11 | martapura
# Processing Record 6 of Set 11 | buique
# Processing Record 7 of Set 11 | zvishavane
# Processing Record 8 of Set 11 | kutum
# Processing Record 9 of Set 11 | pombas
# Processing Record 10 of Set 11 | turlock
# Processing Record 11 of Set 11 | imbituba
# Processing Record 12 of Set 11 | sechura
# Processing Record 13 of Set 11 | inuvik
# Processing Record 14 of Set 11 | waipawa
# Processing Record 15 of Set 11 | ulladulla
# Processing Record 16 of Set 11 | verkhoyansk
# Processing Record 17 of Set 11 | koumac
# Processing Record 18 of Set 11 | grao mogol
# Processing Record 19 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 11 | pocao de pedras
# Processing Record 21 of Set 11 | prince george
# Processing Record 22 of Set 11 | ornskoldsvik
# Processing Record 23 of Set 11 | karasjok
# Processing Record 24 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 25 of Set 11 | okhotsk
# Processing Record 26 of Set 11 | pogar
# Processing Record 27 of Set 11 | marquette
# Processing Record 28 of Set 11 | laguna
# Processing Record 29 of Set 11 | nueva helvecia
# Processing Record 30 of Set 11 | krasnoselkup
# Processing Record 31 of Set 11 | margate
# Processing Record 32 of Set 11 | nieuw amsterdam
# Processing Record 33 of Set 11 | fort saint james
# Processing Record 34 of Set 11 | ribeirao
# Processing Record 35 of Set 11 | santo antonio do ica
# Processing Record 36 of Set 11 | george
# Processing Record 37 of Set 11 | grand gaube
# Processing Record 38 of Set 11 | tateyama
# Processing Record 39 of Set 11 | ibra
# Processing Record 40 of Set 11 | zyryanka
# Processing Record 41 of Set 11 | muros
# Processing Record 42 of Set 11 | beipiao
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 11 | cabo san lucas
# Processing Record 46 of Set 11 | kedrovyy
# Processing Record 47 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 11 | brookings
# Processing Record 49 of Set 11 | vila franca do campo
# Processing Record 50 of Set 11 | danjiangkou
# Processing Record 1 of Set 12 | bathsheba
# Processing Record 2 of Set 12 | kailua
# Processing Record 3 of Set 12 | aquin
# Processing Record 4 of Set 12 | goksun
# Processing Record 5 of Set 12 | la reforma
# Processing Record 6 of Set 12 | namikupa
# Processing Record 7 of Set 12 | dao
# Processing Record 8 of Set 12 | kisangani
# Processing Record 9 of Set 12 | oistins
# Processing Record 10 of Set 12 | nizwa
# Processing Record 11 of Set 12 | senador jose porfirio
# Processing Record 12 of Set 12 | makungu
# Processing Record 13 of Set 12 | teya
# Processing Record 14 of Set 12 | rosetta
# Processing Record 15 of Set 12 | chaohu
# Processing Record 16 of Set 12 | vostok
# Processing Record 17 of Set 12 | ondangwa
# Processing Record 18 of Set 12 | burica
# City not found. Skipping...
# Processing Record 19 of Set 12 | makarov
# Processing Record 20 of Set 12 | varangaon
# Processing Record 21 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 22 of Set 12 | ust-kuyga
# Processing Record 23 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 24 of Set 12 | sao felix do xingu
# Processing Record 25 of Set 12 | montgomery
# Processing Record 26 of Set 12 | bonthe
# Processing Record 27 of Set 12 | naryan-mar
# Processing Record 28 of Set 12 | taseyevo
# Processing Record 29 of Set 12 | maragogi
# Processing Record 30 of Set 12 | gwadar
# Processing Record 31 of Set 12 | knokke-heist
# Processing Record 32 of Set 12 | kipia
# Processing Record 33 of Set 12 | spearfish
# Processing Record 34 of Set 12 | surt
# Processing Record 35 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 36 of Set 12 | garowe
# Processing Record 37 of Set 12 | port shepstone
# Processing Record 38 of Set 12 | bomet
# Processing Record 39 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 12 | les cayes
# Processing Record 41 of Set 12 | daru
# Processing Record 42 of Set 12 | dunn
# Processing Record 43 of Set 12 | ugoofaaru
# Processing Record 44 of Set 12 | corn island
# Processing Record 45 of Set 12 | vanavara
# Processing Record 46 of Set 12 | itarema
# Processing Record 47 of Set 12 | sayyan
# Processing Record 48 of Set 12 | arroio grande
# Processing Record 49 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 50 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 13 | puerto colombia
# Processing Record 2 of Set 13 | lima
# Processing Record 3 of Set 13 | port hardy
# Processing Record 4 of Set 13 | puerto pinasco
# City not found. Skipping...
# Processing Record 5 of Set 13 | hambantota
# Processing Record 6 of Set 13 | praia
# Processing Record 7 of Set 13 | ballina
# Processing Record 8 of Set 13 | fairbanks
# Processing Record 9 of Set 13 | dumas
# Processing Record 10 of Set 13 | talcahuano
# Processing Record 11 of Set 13 | morondava
# Processing Record 12 of Set 13 | bartica
# Processing Record 13 of Set 13 | storforshei
# Processing Record 14 of Set 13 | ljubimec
# City not found. Skipping...
# Processing Record 15 of Set 13 | frecatei
# Processing Record 16 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 13 | yulara
# Processing Record 18 of Set 13 | mitsamiouli
# Processing Record 19 of Set 13 | zhigansk
# Processing Record 20 of Set 13 | torrington
# Processing Record 21 of Set 13 | vitim
# Processing Record 22 of Set 13 | aswan
# Processing Record 23 of Set 13 | griffith
# Processing Record 24 of Set 13 | novikovo
# Processing Record 25 of Set 13 | paita
# Processing Record 26 of Set 13 | columbia
# Processing Record 27 of Set 13 | sitges
# Processing Record 28 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | bima
# Processing Record 30 of Set 13 | atherton
# Processing Record 31 of Set 13 | nalut
# Processing Record 32 of Set 13 | berdigestyakh
# Processing Record 33 of Set 13 | broken hill
# Processing Record 34 of Set 13 | uige
# Processing Record 35 of Set 13 | shaunavon
# Processing Record 36 of Set 13 | gombe
# Processing Record 37 of Set 13 | ust-tsilma
# Processing Record 38 of Set 13 | los llanos de aridane
# Processing Record 39 of Set 13 | coahuayana
# Processing Record 40 of Set 13 | borovoy
# Processing Record 41 of Set 13 | tkibuli
# Processing Record 42 of Set 13 | yara
# Processing Record 43 of Set 13 | juan lacaze
# Processing Record 44 of Set 13 | rock springs
# Processing Record 45 of Set 13 | nishihara
# Processing Record 46 of Set 13 | kondinskoye
# Processing Record 47 of Set 13 | derbent
# Processing Record 48 of Set 13 | inirida
# Processing Record 49 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 13 | cajibio
# Processing Record 1 of Set 14 | chimore
# Processing Record 2 of Set 14 | chiredzi
# Processing Record 3 of Set 14 | banyo
# Processing Record 4 of Set 14 | puerto cabezas
# Processing Record 5 of Set 14 | sangar
# Processing Record 6 of Set 14 | atambua
# Processing Record 7 of Set 14 | stepnyak
# Processing Record 8 of Set 14 | poso
# Processing Record 9 of Set 14 | wanparti
# Processing Record 10 of Set 14 | rafaela
# Processing Record 11 of Set 14 | naze
# Processing Record 12 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 14 | nevel
# Processing Record 14 of Set 14 | progreso
# Processing Record 15 of Set 14 | caiaponia
# Processing Record 16 of Set 14 | djang
# City not found. Skipping...
# Processing Record 17 of Set 14 | ouegoa
# Processing Record 18 of Set 14 | juigalpa
# Processing Record 19 of Set 14 | takoradi
# Processing Record 20 of Set 14 | atar
# Processing Record 21 of Set 14 | santiago del estero
# Processing Record 22 of Set 14 | xai-xai
# Processing Record 23 of Set 14 | tilichiki
# Processing Record 24 of Set 14 | manta
# Processing Record 25 of Set 14 | mangai
# Processing Record 26 of Set 14 | haikou
# Processing Record 27 of Set 14 | hami
# Processing Record 28 of Set 14 | chulym
# Processing Record 29 of Set 14 | yabrud
# Processing Record 30 of Set 14 | iquique
# Processing Record 31 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 14 | amapa
# Processing Record 33 of Set 14 | sabha
# Processing Record 34 of Set 14 | bom jesus da lapa
# Processing Record 35 of Set 14 | uvinza
# Processing Record 36 of Set 14 | limbang
# Processing Record 37 of Set 14 | kilindoni
# Processing Record 38 of Set 14 | kharp
# Processing Record 39 of Set 14 | lincoln
# Processing Record 40 of Set 14 | agua dulce
# Processing Record 41 of Set 14 | mana
# Processing Record 42 of Set 14 | nacogdoches
# Processing Record 43 of Set 14 | auning
# Processing Record 44 of Set 14 | sault sainte marie
# Processing Record 45 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 46 of Set 14 | polunochnoye
# Processing Record 47 of Set 14 | barrie
# Processing Record 48 of Set 14 | oudtshoorn
# Processing Record 49 of Set 14 | dharchula
# Processing Record 50 of Set 14 | ajaccio
# Processing Record 1 of Set 15 | orebro
# Processing Record 2 of Set 15 | batemans bay
# Processing Record 3 of Set 15 | puerto escondido
# Processing Record 4 of Set 15 | tottori
# Processing Record 5 of Set 15 | trapani
# Processing Record 6 of Set 15 | merauke
# Processing Record 7 of Set 15 | maryville
# Processing Record 8 of Set 15 | matagami
# Processing Record 9 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 15 | parsons
# Processing Record 11 of Set 15 | dwarka
# Processing Record 12 of Set 15 | tautira
# Processing Record 13 of Set 15 | marigot
# Processing Record 14 of Set 15 | raudeberg
# Processing Record 15 of Set 15 | meulaboh
# Processing Record 16 of Set 15 | awbari
# Processing Record 17 of Set 15 | presidencia roque saenz pena
# Processing Record 18 of Set 15 | tazovskiy
# Processing Record 19 of Set 15 | olovyannaya
# Processing Record 20 of Set 15 | birao
# Processing Record 21 of Set 15 | shimanovsk
# Processing Record 22 of Set 15 | barra patuca
# Processing Record 23 of Set 15 | wattegama
# Processing Record 24 of Set 15 | lalmohan
# Processing Record 25 of Set 15 | bloemfontein
# Processing Record 26 of Set 15 | bermeo
# Processing Record 27 of Set 15 | grand baie
# Processing Record 28 of Set 15 | coruripe
# Processing Record 29 of Set 15 | lewiston
# Processing Record 30 of Set 15 | zorritos
# Processing Record 31 of Set 15 | almaznyy
# Processing Record 32 of Set 15 | izhma
# Processing Record 33 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 15 | cabedelo
# Processing Record 35 of Set 15 | beaverlodge
# Processing Record 36 of Set 15 | ellensburg
# Processing Record 37 of Set 15 | athens
# Processing Record 38 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 15 | labuhan
# Processing Record 40 of Set 15 | sayabec
# City not found. Skipping...
# Processing Record 41 of Set 15 | gasa
# Processing Record 42 of Set 15 | paragominas
# Processing Record 43 of Set 15 | caravelas
# Processing Record 44 of Set 15 | galesong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert array of dictionaries to pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Susangerd      IR  31.5608   48.1831     75.36        14           0
# 1      Khatanga      RU  71.9667  102.5000      5.90        95          99
# 2       Antalya      TR  36.7741   30.7178     65.08        54          75
# 3         Vaini      TO -21.2000 -175.2000     82.56        83          75
# 4  Longyearbyen      SJ  78.2186   15.6401     21.04        86          75
# 5        Nabire      ID  -3.3667  135.4833     75.38        91          93
# 6      Hermanus      ZA -34.4187   19.2345     61.81        89          36
# 7          Shar      KZ  49.5886   81.0453     50.94        32          52
# 8       Mataura      NZ -46.1927  168.8643     41.49        81           0
# 9      Karratha      AU -20.7377  116.8463     83.43        35          18
#
#    Wind Speed Current Description
# 0       16.13           clear sky
# 1       12.35     overcast clouds
# 2       10.36          light rain
# 3        4.61       broken clouds
# 4       12.66          light snow
# 5        2.86       moderate rain
# 6        8.46    scattered clouds
# 7        8.10       broken clouds
# 8        1.74           clear sky
# 9       10.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
